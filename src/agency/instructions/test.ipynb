# %%
# %pip install youtube_transcript_api
# Out:
# ...
#   Using cached youtube_transcript_api-1.2.3-py3-none-any.whl.metadata (24 kB)
# ...
# Using cached youtube_transcript_api-1.2.3-py3-none-any.whl (485 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
tscp = ytt_api.fetch('Fg8VHXr-WVM', preserve_formatting=True)

# %%
help(tscp)
# Out:
# Help on FetchedTranscript in module youtube_transcript_api._transcripts object:
#
# class FetchedTranscript(builtins.object)
#  |  FetchedTranscript(snippets: List[youtube_transcript_api._transcripts.FetchedTranscriptSnippet], video_id: str, language: str, language_code: str, is_generated: bool) -> None
#  |
#  |  Represents a fetched transcript. This object is iterable, which allows you to
#  |  iterate over the transcript snippets.
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getitem__(self, index) -> youtube_transcript_api._transcripts.FetchedTranscriptSnippet
#  |
#  |  __init__(self, snippets: List[youtube_transcript_api._transcripts.FetchedTranscriptSnippet], video_id: str, language: str, language_code: str, is_generated: bool) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self) -> Iterator[youtube_transcript_api._transcripts.FetchedTranscriptSnippet]
#  |
# ...

# %%
tscp
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='In my last video, I showed a new method', start=0.08, duration=5.12), FetchedTranscriptSnippet(text='proposed by Anthropic called MCP code', start=2.32, duration=5.439), FetchedTranscriptSnippet(text='execution. This technique is the future', start=5.2, duration=5.04), FetchedTranscriptSnippet(text='of building AI agents because it reduces', start=7.759, duration=6.161), FetchedTranscriptSnippet(text='token consumption 98% while giving your', start=10.24, duration=6.56), FetchedTranscriptSnippet(text='agents way more autonomy and flexibility', start=13.92, duration=5.439), FetchedTranscriptSnippet(text='to evolve their own skills. In this', start=16.8, duration=4.479), FetchedTranscriptSnippet(text="video, I'll build this life with you", start=19.359, duration=4.0), FetchedTranscriptSnippet(text="step by step. I'll compare this new", start=21.279, duration=4.561), FetchedTranscriptSnippet(text='approach with the old direct MC
# ...

# %%
with open('video.txt', 'w') as f:
    f.write(" ".join([ ele['text'] for ele in tscp.to_raw_data()]))
