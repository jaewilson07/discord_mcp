# %%
# %pip install youtube_transcript_api
# Out:
# Note: you may need to restart the kernel to use updated packages.
# d:\GitHub\mcp-discord\.venv\Scripts\python.exe: No module named pip

# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
tscp = ytt_api.fetch('https://www.youtube.com/watch?v=Fg8VHXr-WVM')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from youtube_transcript_api import YouTubeTranscriptApi
#       3 ytt_api = YouTubeTranscriptApi()
#       4 tscp = ytt_api.fetch('https://www.youtube.com/watch?v=Fg8VHXr-WVM')
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
